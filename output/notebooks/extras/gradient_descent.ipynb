# %% [markdown]
# # Gradient Descent
#
# Source orchestrators: `extras/gradient_descent/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import sys
import warnings

import matplotlib.pyplot as plt

# Locate the repository root at runtime (not the export machine's path):
# walk up from the notebook's working directory to the folder containing
# both `src/active_inference` and `chapters/`. This keeps a clean clone of
# the repo runnable regardless of who generated the notebook.
def _find_repo_root(start=None):
    here = Path(start or Path.cwd()).resolve()
    for candidate in [here, *here.parents]:
        if (candidate / 'src' / 'active_inference').is_dir() and (candidate / 'chapters').is_dir():
            return candidate
    return here

REPO_ROOT = _find_repo_root()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_gradient_descent`
#
# **Animation** — Animate the Gradient Descent extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/gradient_descent/animation_gradient_descent.npz`, `output/data/extras/gradient_descent/animation_gradient_descent.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/gradient_descent/animation_gradient_descent.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/gradient_descent/animation_gradient_descent.gif')))

# %% [markdown]
# ## `interactive_gradient_descent`
#
# **Interactive** — Interactively explore the Gradient Descent extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/gradient_descent/interactive_gradient_descent.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_gradient_descent`
#
# **Simulation** — Simulate the Gradient Descent extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/gradient_descent/simulate_gradient_descent.py', run_name='__main__')

# %% [markdown]
# ## `visualize_gradient_descent`
#
# **Visualization** — Visualize the Gradient Descent extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/gradient_descent/visualize_gradient_descent.py', run_name='__main__')
