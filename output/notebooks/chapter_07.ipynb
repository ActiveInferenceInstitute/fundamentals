# %% [markdown]
# # Chapter 07
#
# Source orchestrators: `chapters/chapter_07/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import sys
import warnings

import matplotlib.pyplot as plt

# Locate the repository root at runtime (not the export machine's path):
# walk up from the notebook's working directory to the folder containing
# both `src/active_inference` and `chapters/`. This keeps a clean clone of
# the repo runnable regardless of who generated the notebook.
def _find_repo_root(start=None):
    here = Path(start or Path.cwd()).resolve()
    for candidate in [here, *here.parents]:
        if (candidate / 'src' / 'active_inference').is_dir() and (candidate / 'chapters').is_dir():
            return candidate
    return here

REPO_ROOT = _find_repo_root()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_7_5_multivariate_active_inference`
#
# **Animation** — Animation - Chapter 7 section 7.5 multivariate active generalized filtering.
#
# Raw data (after `--save`): `output/data/chapter_07/animation_7_5_multivariate_active_inference.npz`, `output/data/chapter_07/animation_7_5_multivariate_active_inference.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_07/animation_7_5_multivariate_active_inference.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_07/animation_7_5_multivariate_active_inference.gif')))

# %% [markdown]
# ## `example_7_2_active_inference`
#
# **Example** — Example 7.2 — active inference: countering an exogenous force (Chapter 7 §7.4).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_07/example_7_2_active_inference.py', run_name='__main__')

# %% [markdown]
# ## `example_7_5_multivariate_active_inference`
#
# **Example** — Example 7.5 - multivariate active generalized filtering.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_07/example_7_5_multivariate_active_inference.py', run_name='__main__')
