# %% [markdown]
# # Chapter 02
#
# Source orchestrators: `chapters/chapter_02/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import sys
import warnings

import matplotlib.pyplot as plt

# Locate the repository root at runtime (not the export machine's path):
# walk up from the notebook's working directory to the folder containing
# both `src/active_inference` and `chapters/`. This keeps a clean clone of
# the repo runnable regardless of who generated the notebook.
def _find_repo_root(start=None):
    here = Path(start or Path.cwd()).resolve()
    for candidate in [here, *here.parents]:
        if (candidate / 'src' / 'active_inference').is_dir() and (candidate / 'chapters').is_dir():
            return candidate
    return here

REPO_ROOT = _find_repo_root()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_gradient_descent`
#
# **Animation** — Bonus — animated gradient descent for the MLE / MAP loss.
#
# Raw data (after `--save`): `output/data/chapter_02/animation_gradient_descent.npz`, `output/data/chapter_02/animation_gradient_descent.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_02/animation_gradient_descent.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_02/animation_gradient_descent.gif')))

# %% [markdown]
# ## `animation_sequential`
#
# **Animation** — Bonus — animated sequential Bayesian update for Chapter 2.
#
# Raw data (after `--save`): `output/data/chapter_02/animation_sequential.npz`, `output/data/chapter_02/animation_sequential.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_02/animation_sequential.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_02/animation_sequential.gif')))

# %% [markdown]
# ## `example_2_10_gradient_descent`
#
# **Example** — Section 2.5.2 - Iterative MLE / MAP via gradient descent.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/example_2_10_gradient_descent.py', run_name='__main__')

# %% [markdown]
# ## `example_2_1_linear_deterministic`
#
# **Example** — Example 2.1 — Linear, deterministic generative model.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/example_2_1_linear_deterministic.py', run_name='__main__')

# %% [markdown]
# ## `example_2_2_linear_probabilistic`
#
# **Example** — Example 2.2 — Linear, probabilistic generative model.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/example_2_2_linear_probabilistic.py', run_name='__main__')

# %% [markdown]
# ## `example_2_3_precision`
#
# **Example** — Example 2.3 — Trust the data or trust the prior?

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/example_2_3_precision.py', run_name='__main__')

# %% [markdown]
# ## `example_2_4_nonlinear_deterministic`
#
# **Example** — Example 2.4 — Nonlinear, deterministic generative model.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/example_2_4_nonlinear_deterministic.py', run_name='__main__')

# %% [markdown]
# ## `example_2_5_nonlinear_probabilistic`
#
# **Example** — Example 2.5 — Nonlinear, probabilistic generative model.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/example_2_5_nonlinear_probabilistic.py', run_name='__main__')

# %% [markdown]
# ## `example_2_6_imperfect_model`
#
# **Example** — Example 2.6 — Mismatched generative model and generative process.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/example_2_6_imperfect_model.py', run_name='__main__')

# %% [markdown]
# ## `example_2_7_multiple_samples`
#
# **Example** — Example 2.7 - Bayesian inference from a batch of i.i.d. observations.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/example_2_7_multiple_samples.py', run_name='__main__')

# %% [markdown]
# ## `example_2_8_mle_analytic`
#
# **Example** — Example 2.8 — Closed-form maximum likelihood estimation.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/example_2_8_mle_analytic.py', run_name='__main__')

# %% [markdown]
# ## `example_2_9_map_analytic`
#
# **Example** — Example 2.9 — Closed-form maximum a posteriori estimation.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/example_2_9_map_analytic.py', run_name='__main__')

# %% [markdown]
# ## `interactive_explorer`
#
# **Interactive** — Bonus — Slider-driven explorer for the canonical linear-Gaussian agent.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python chapters/chapter_02/interactive_explorer.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `interactive_gradient_descent`
#
# **Interactive** — Chapter 2 · Interactive gradient-descent trajectory scrubber (GUI / web-launchable).
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python chapters/chapter_02/interactive_gradient_descent.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `visualize_generative_model`
#
# **Visualization** — §2.4 — Visualizing the joint density p(x, y) of an agent's generative model.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_02/visualize_generative_model.py', run_name='__main__')
