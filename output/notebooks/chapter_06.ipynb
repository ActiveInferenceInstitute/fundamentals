# %% [markdown]
# # Chapter 06
#
# Source orchestrators: `chapters/chapter_06/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import sys
import warnings

import matplotlib.pyplot as plt

# Locate the repository root at runtime (not the export machine's path):
# walk up from the notebook's working directory to the folder containing
# both `src/active_inference` and `chapters/`. This keeps a clean clone of
# the repo runnable regardless of who generated the notebook.
def _find_repo_root(start=None):
    here = Path(start or Path.cwd()).resolve()
    for candidate in [here, *here.parents]:
        if (candidate / 'src' / 'active_inference').is_dir() and (candidate / 'chapters').is_dir():
            return candidate
    return here

REPO_ROOT = _find_repo_root()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `example_6_1_generalized_filter`
#
# **Example** — Example 6.1 — univariate generalized filtering for perception (Chapter 6).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_06/example_6_1_generalized_filter.py', run_name='__main__')

# %% [markdown]
# ## `example_6_2_multivariate_filter`
#
# **Example** — Example 6.2 — the multivariate generalized filter (Chapter 6 §6.2).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_06/example_6_2_multivariate_filter.py', run_name='__main__')

# %% [markdown]
# ## `example_6_6_generalized_coordinates`
#
# **Example** — Example 6.6 — univariate generalized filtering in generalized coordinates (§6.5).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_06/example_6_6_generalized_coordinates.py', run_name='__main__')

# %% [markdown]
# ## `example_6_7_multivariate_generalized_coordinates`
#
# **Example** — Example 6.7 - multivariate generalized filtering in generalized coordinates.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_06/example_6_7_multivariate_generalized_coordinates.py', run_name='__main__')

# %% [markdown]
# ## `visualize_6_6_correlated_embedding_orders`
#
# **Visualization** — Visualize Chapter 6 §6.6 correlated embedding-order precision matrices.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_06/visualize_6_6_correlated_embedding_orders.py', run_name='__main__')
