# %% [markdown]
# # Chapter 01
#
# Source orchestrators: `chapters/chapter_01/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import sys
import warnings

import matplotlib.pyplot as plt

# Locate the repository root at runtime (not the export machine's path):
# walk up from the notebook's working directory to the folder containing
# both `src/active_inference` and `chapters/`. This keeps a clean clone of
# the repo runnable regardless of who generated the notebook.
def _find_repo_root(start=None):
    here = Path(start or Path.cwd()).resolve()
    for candidate in [here, *here.parents]:
        if (candidate / 'src' / 'active_inference').is_dir() and (candidate / 'chapters').is_dir():
            return candidate
    return here

REPO_ROOT = _find_repo_root()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `01_box_scenario`
#
# **Concept** — Chapter 1 · Box scenario — an agent receives a stream of noisy sensor readings.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_01/01_box_scenario.py', run_name='__main__')

# %% [markdown]
# ## `02_three_perspectives`
#
# **Concept** — Chapter 1 · Three perspectives on what a "model" is.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_01/02_three_perspectives.py', run_name='__main__')

# %% [markdown]
# ## `03_bayes_intuition`
#
# **Concept** — Chapter 1 · Walking through Bayes' theorem one factor at a time.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_01/03_bayes_intuition.py', run_name='__main__')

# %% [markdown]
# ## `04_inverse_problem`
#
# **Concept** — Chapter 1 · The inverse problem becomes ill-posed for non-injective generators.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_01/04_inverse_problem.py', run_name='__main__')

# %% [markdown]
# ## `05_belief_from_stream`
#
# **Concept** — Chapter 1 · Animated belief formation from the box-scenario sensor stream.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_01/05_belief_from_stream.py', run_name='__main__')

# %% [markdown]
# ## `interactive_inverse_problem`
#
# **Interactive** — Chapter 1 · Interactive inverse-problem explorer (GUI / web-launchable).
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python chapters/chapter_01/interactive_inverse_problem.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.
