# %% [markdown]
# # Chapter 04
#
# Source orchestrators: `chapters/chapter_04/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import sys
import warnings

import matplotlib.pyplot as plt

# Locate the repository root at runtime (not the export machine's path):
# walk up from the notebook's working directory to the folder containing
# both `src/active_inference` and `chapters/`. This keeps a clean clone of
# the repo runnable regardless of who generated the notebook.
def _find_repo_root(start=None):
    here = Path(start or Path.cwd()).resolve()
    for candidate in [here, *here.parents]:
        if (candidate / 'src' / 'active_inference').is_dir() and (candidate / 'chapters').is_dir():
            return candidate
    return here

REPO_ROOT = _find_repo_root()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_vfe_descent`
#
# **Animation** — Animation — variational free energy descent (Chapter 4, bonus).
#
# Raw data (after `--save`): `output/data/chapter_04/animation_vfe_descent.npz`, `output/data/chapter_04/animation_vfe_descent.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_04/animation_vfe_descent.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_04/animation_vfe_descent.gif')))

# %% [markdown]
# ## `example_4_1_coordinate_search`
#
# **Example** — Example 4.1 — Finding the minima of VFE with coordinate search (§4.2).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_04/example_4_1_coordinate_search.py', run_name='__main__')

# %% [markdown]
# ## `example_4_2_surprisal`
#
# **Example** — Example 4.2 — Surprisal and the marginal likelihood (§4.3).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_04/example_4_2_surprisal.py', run_name='__main__')

# %% [markdown]
# ## `example_4_3_vfe_forms`
#
# **Example** — Examples 4.3–4.5 — The G, C, and E forms of variational free energy (§4.4).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_04/example_4_3_vfe_forms.py', run_name='__main__')

# %% [markdown]
# ## `example_4_6_free_form_cavi`
#
# **Example** — Example 4.6 — Free-form mean-field coordinate-ascent VI (§4.5).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_04/example_4_6_free_form_cavi.py', run_name='__main__')

# %% [markdown]
# ## `example_4_7_fixed_form`
#
# **Example** — Example 4.7 — Fixed-form variational inference (§4.6).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_04/example_4_7_fixed_form.py', run_name='__main__')

# %% [markdown]
# ## `interactive_vfe_explorer`
#
# **Interactive** — Chapter 4 (bonus) · Interactive variational free energy explorer (GUI / web-launchable).
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python chapters/chapter_04/interactive_vfe_explorer.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `visualize_kl_loss`
#
# **Visualization** — §4.1 — KL divergence as a loss function for the posterior.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_04/visualize_kl_loss.py', run_name='__main__')

# %% [markdown]
# ## `visualize_model_comparison`
#
# **Visualization** — §4.3 — Model evidence and Bayesian model comparison (Figs. 4.3.2 / 4.3.3).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_04/visualize_model_comparison.py', run_name='__main__')

# %% [markdown]
# ## `visualize_vfe_intuition`
#
# **Visualization** — §4.2 — Intuition for the G-form of variational free energy (Fig. 4.2.3).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_04/visualize_vfe_intuition.py', run_name='__main__')
