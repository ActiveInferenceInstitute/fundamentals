# %% [markdown]
# # Chapter 12
#
# Source orchestrators: `chapters/chapter_12/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import sys
import warnings

import matplotlib.pyplot as plt

# Locate the repository root at runtime (not the export machine's path):
# walk up from the notebook's working directory to the folder containing
# both `src/active_inference` and `chapters/`. This keeps a clean clone of
# the repo runnable regardless of who generated the notebook.
def _find_repo_root(start=None):
    here = Path(start or Path.cwd()).resolve()
    for candidate in [here, *here.parents]:
        if (candidate / 'src' / 'active_inference').is_dir() and (candidate / 'chapters').is_dir():
            return candidate
    return here

REPO_ROOT = _find_repo_root()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `example_12_1_factor_graph_messages`
#
# **Example** — Example 12.1 - forward/backward messages in a categorical factor graph.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_12/example_12_1_factor_graph_messages.py', run_name='__main__')

# %% [markdown]
# ## `example_12_2_belief_propagation_smoothing`
#
# **Example** — Example 12.2 - sum-product belief propagation and backward smoothing.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_12/example_12_2_belief_propagation_smoothing.py', run_name='__main__')

# %% [markdown]
# ## `example_12_3_vmp_marginal_messages`
#
# **Example** — Example 12.3 - variational and marginal message passing.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_12/example_12_3_vmp_marginal_messages.py', run_name='__main__')

# %% [markdown]
# ## `example_12_4_hybrid_message_bridge`
#
# **Example** — Example 12.4 - VMP messages and a hybrid discrete/continuous bridge.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_12/example_12_4_hybrid_message_bridge.py', run_name='__main__')

# %% [markdown]
# ## `example_12_5_active_factor_learning_attention`
#
# **Example** — Example 12.5 - active-inference factor messages with learning/attention.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_12/example_12_5_active_factor_learning_attention.py', run_name='__main__')
