# %% [markdown]
# # Chapter 03
#
# Source orchestrators: `chapters/chapter_03/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import sys
import warnings

import matplotlib.pyplot as plt

# Locate the repository root at runtime (not the export machine's path):
# walk up from the notebook's working directory to the folder containing
# both `src/active_inference` and `chapters/`. This keeps a clean clone of
# the repo runnable regardless of who generated the notebook.
def _find_repo_root(start=None):
    here = Path(start or Path.cwd()).resolve()
    for candidate in [here, *here.parents]:
        if (candidate / 'src' / 'active_inference').is_dir() and (candidate / 'chapters').is_dir():
            return candidate
    return here

REPO_ROOT = _find_repo_root()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_bimodal_emergence`
#
# **Animation** — Bonus animation — bimodality emerging from a non-injective generator.
#
# Raw data (after `--save`): `output/data/chapter_03/animation_bimodal_emergence.npz`, `output/data/chapter_03/animation_bimodal_emergence.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_03/animation_bimodal_emergence.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_03/animation_bimodal_emergence.gif')))

# %% [markdown]
# ## `animation_blr_predictive_band`
#
# **Animation** — Bonus animation — Bayesian linear regression predictive band collapse.
#
# Raw data (after `--save`): `output/data/chapter_03/animation_blr_predictive_band.npz`, `output/data/chapter_03/animation_blr_predictive_band.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_03/animation_blr_predictive_band.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_03/animation_blr_predictive_band.gif')))

# %% [markdown]
# ## `animation_blr_tightening`
#
# **Animation** — Bonus — animated Bayesian linear regression posterior tightening.
#
# Raw data (after `--save`): `output/data/chapter_03/animation_blr_tightening.npz`, `output/data/chapter_03/animation_blr_tightening.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_03/animation_blr_tightening.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_03/animation_blr_tightening.gif')))

# %% [markdown]
# ## `animation_em_convergence`
#
# **Animation** — Bonus — animated EM convergence for factor analysis.
#
# Raw data (after `--save`): `output/data/chapter_03/animation_em_convergence.npz`, `output/data/chapter_03/animation_em_convergence.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_03/animation_em_convergence.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_03/animation_em_convergence.gif')))

# %% [markdown]
# ## `animation_em_steps`
#
# **Animation** — Bonus animation — alternating E and M steps in factor-analysis EM.
#
# Raw data (after `--save`): `output/data/chapter_03/animation_em_steps.npz`, `output/data/chapter_03/animation_em_steps.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_03/animation_em_steps.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_03/animation_em_steps.gif')))

# %% [markdown]
# ## `animation_lgs_online`
#
# **Animation** — Bonus animation — LGS sensor fusion one observation at a time.
#
# Raw data (after `--save`): `output/data/chapter_03/animation_lgs_online.npz`, `output/data/chapter_03/animation_lgs_online.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_03/animation_lgs_online.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_03/animation_lgs_online.gif')))

# %% [markdown]
# ## `animation_precision_sweep`
#
# **Animation** — Bonus animation — sweep the prior↔data precision tradeoff.
#
# Raw data (after `--save`): `output/data/chapter_03/animation_precision_sweep.npz`, `output/data/chapter_03/animation_precision_sweep.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_03/animation_precision_sweep.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_03/animation_precision_sweep.gif')))

# %% [markdown]
# ## `animation_sufficient_statistics`
#
# **Animation** — Diagnostic animation — running posterior mean / std / KL[post||prior] vs N.
#
# Raw data (after `--save`): `output/data/chapter_03/animation_sufficient_statistics.npz`, `output/data/chapter_03/animation_sufficient_statistics.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_03/animation_sufficient_statistics.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_03/animation_sufficient_statistics.gif')))

# %% [markdown]
# ## `example_3_1_linear_regression_mle`
#
# **Example** — Example 3.1 — Closed-form linear regression at low sample sizes.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_03/example_3_1_linear_regression_mle.py', run_name='__main__')

# %% [markdown]
# ## `example_3_2_linear_regression_gd`
#
# **Example** — Example 3.2 — Linear regression by gradient descent.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_03/example_3_2_linear_regression_gd.py', run_name='__main__')

# %% [markdown]
# ## `example_3_3_multiple_regression`
#
# **Example** — Example 3.3 — Multiple linear regression via the normal equation.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_03/example_3_3_multiple_regression.py', run_name='__main__')

# %% [markdown]
# ## `example_3_4_multivariate_gaussian`
#
# **Example** — Example 3.4 — Anatomy of a multivariate normal distribution.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_03/example_3_4_multivariate_gaussian.py', run_name='__main__')

# %% [markdown]
# ## `example_3_5_bayesian_linear_regression`
#
# **Example** — Example 3.5 - Bayesian linear regression.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_03/example_3_5_bayesian_linear_regression.py', run_name='__main__')

# %% [markdown]
# ## `example_3_6_lgs_food_localization`
#
# **Example** — Example 3.6 — Multivariate hidden-state inference via the LGS.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_03/example_3_6_lgs_food_localization.py', run_name='__main__')

# %% [markdown]
# ## `example_3_7_factor_analysis_em`
#
# **Example** — Example 3.7 - Factor analysis via expectation-maximization.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_03/example_3_7_factor_analysis_em.py', run_name='__main__')

# %% [markdown]
# ## `interactive_bayesian_regression`
#
# **Interactive** — Chapter 3 · Interactive Bayesian linear regression (GUI / web-launchable).
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python chapters/chapter_03/interactive_bayesian_regression.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `interactive_lgs_localization`
#
# **Interactive** — Chapter 3 · Interactive 2-D LGS food-localization explorer (GUI / web-launchable).
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python chapters/chapter_03/interactive_lgs_localization.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `visualize_calibration`
#
# **Visualization** — Diagnostic — reliability diagram for the Bayesian linear regression posterior.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_03/visualize_calibration.py', run_name='__main__')

# %% [markdown]
# ## `visualize_coverage`
#
# **Visualization** — Diagnostic — empirical coverage of a 95% credible interval as N grows.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_03/visualize_coverage.py', run_name='__main__')

# %% [markdown]
# ## `visualize_posterior_predictive`
#
# **Visualization** — Diagnostic — posterior predictive check for the BLR fit.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_03/visualize_posterior_predictive.py', run_name='__main__')
