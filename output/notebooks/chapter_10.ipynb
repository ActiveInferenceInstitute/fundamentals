# %% [markdown]
# # Chapter 10
#
# Source orchestrators: `chapters/chapter_10/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import sys
import warnings

import matplotlib.pyplot as plt

# Locate the repository root at runtime (not the export machine's path):
# walk up from the notebook's working directory to the folder containing
# both `src/active_inference` and `chapters/`. This keeps a clean clone of
# the repo runnable regardless of who generated the notebook.
def _find_repo_root(start=None):
    here = Path(start or Path.cwd()).resolve()
    for candidate in [here, *here.parents]:
        if (candidate / 'src' / 'active_inference').is_dir() and (candidate / 'chapters').is_dir():
            return candidate
    return here

REPO_ROOT = _find_repo_root()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_bandit`
#
# **Animation** — Animation — the two-armed bandit agent over time (Chapter 10 §10.3, Figs 10.3.6/7).
#
# Raw data (after `--save`): `output/data/chapter_10/animation_bandit.npz`, `output/data/chapter_10/animation_bandit.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_10/animation_bandit.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_10/animation_bandit.gif')))

# %% [markdown]
# ## `animation_learning`
#
# **Animation** — Animation — Dirichlet parameter learning over trials (Chapter 10 §10.1).
#
# Raw data (after `--save`): `output/data/chapter_10/animation_learning.npz`, `output/data/chapter_10/animation_learning.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_10/animation_learning.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_10/animation_learning.gif')))

# %% [markdown]
# ## `animation_precision`
#
# **Animation** — Animation — policy posterior as precision γ sweeps (Chapter 10 §10.2, Example 10.5).
#
# Raw data (after `--save`): `output/data/chapter_10/animation_precision.npz`, `output/data/chapter_10/animation_precision.json`.

# %%
import subprocess
from IPython.display import Image, display

plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_10/animation_precision.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_10/animation_precision.gif')))

# %% [markdown]
# ## `example_10_1_learn_D`
#
# **Example** — Example 10.1 — learning the state-prior vector ``D`` (Chapter 10, §10.1).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_10/example_10_1_learn_D.py', run_name='__main__')

# %% [markdown]
# ## `example_10_2_learn_A`
#
# **Example** — Example 10.2 — learning the likelihood matrix ``A`` (Chapter 10, §10.1).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_10/example_10_2_learn_A.py', run_name='__main__')

# %% [markdown]
# ## `example_10_3_learn_B`
#
# **Example** — Example 10.3 — learning the transition matrix ``B`` (Chapter 10, §10.1).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_10/example_10_3_learn_B.py', run_name='__main__')

# %% [markdown]
# ## `example_10_4_novelty`
#
# **Example** — Example 10.4 — parameter information gain (novelty) and novelty-driven learning (§10.1).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_10/example_10_4_novelty.py', run_name='__main__')

# %% [markdown]
# ## `example_10_5_precision`
#
# **Example** — Example 10.5 — precision- and habit-based policy optimization (Chapter 10, §10.2).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_10/example_10_5_precision.py', run_name='__main__')

# %% [markdown]
# ## `example_10_6_precision_learning`
#
# **Example** — Example 10.6 — learning the policy precision γ from data (Chapter 10, §10.2).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_10/example_10_6_precision_learning.py', run_name='__main__')

# %% [markdown]
# ## `example_10_7_two_armed_bandit`
#
# **Example** — Example 10.7 — the two-armed bandit task (Chapter 10, §10.3 factorial depth).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_10/example_10_7_two_armed_bandit.py', run_name='__main__')

# %% [markdown]
# ## `example_10_8_hierarchical`
#
# **Example** — Example 10.8 — hierarchical depth in POMDPs (Chapter 10, §10.4, nested time scales).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_10/example_10_8_hierarchical.py', run_name='__main__')

# %% [markdown]
# ## `visualize_factorial_structure`
#
# **Visualization** — Visualize the factorial likelihood structure of the two-armed bandit (§10.3, Fig 10.3.4).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_10/visualize_factorial_structure.py', run_name='__main__')
